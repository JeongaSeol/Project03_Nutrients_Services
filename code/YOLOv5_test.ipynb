# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !ls -l /usr/local
# Out:
# total 72
# drwxr-xr-x  1 root root 4096 Nov 29 18:02 bin
# lrwxrwxrwx  1 root root   22 Nov 18 14:29 cuda -> /etc/alternatives/cuda
# drwxr-xr-x 16 root root 4096 Nov 18 14:20 cuda-10.0
# drwxr-xr-x 15 root root 4096 Nov 18 14:23 cuda-10.1
# lrwxrwxrwx  1 root root   25 Nov 18 14:29 cuda-11 -> /etc/alternatives/cuda-11
# drwxr-xr-x 15 root root 4096 Nov 18 14:25 cuda-11.0
# drwxr-xr-x  1 root root 4096 Nov 18 14:27 cuda-11.1
# drwxr-xr-x  1 root root 4096 Nov 29 17:33 etc
# drwxr-xr-x  2 root root 4096 Nov 19  2020 games
# drwxr-xr-x  2 root root 4096 Nov 29 17:45 _gcs_config_ops.so
# drwxr-xr-x  1 root root 4096 Nov 29 17:53 include
# drwxr-xr-x  1 root root 4096 Nov 29 17:54 lib
# -rw-r--r--  1 root root 1636 Nov 29 17:49 LICENSE.txt
# drwxr-xr-x  3 root root 4096 Nov 29 17:45 licensing
# lrwxrwxrwx  1 root root    9 Nov 19  2020 man -> share/man
# drwxr-xr-x  2 root root 4096 Nov 19  2020 sbin
# -rw-r--r--  1 root root 7291 Nov 29 17:49 setup.cfg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/yolov5

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# !ls -l '/content/drive/My Drive/Colab Notebooks/datasets/final_img.zip'
# Out:
# -rw------- 1 root root 143248122 Nov 12 06:04 '/content/drive/My Drive/Colab Notebooks/datasets/final_img.zip'

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/datasets/final_img.zip'
# Out:
# Archive:  /content/drive/My Drive/Colab Notebooks/datasets/final_img.zip
#   inflating: img/classes.txt
#   inflating: img/val/배추김치_77.jpg
#   inflating: img/val/조미김_54.txt
#   inflating: img/val/조미김_36.txt
#   inflating: img/val/김 김치 쌀밥_92.txt
#   inflating: img/val/김 김치 쌀밥_78.txt
#   inflating: img/val/흰쌀밥21.jpg
#   inflating: img/val/조미김_62.txt
#   inflating: img/val/조미김8.txt
#   inflating: img/val/김 김치 쌀밥_60.txt
#   inflating: img/val/김 김치 쌀밥_82.txt
#   inflating: img/val/조미김정식_5.txt
#   inflating: img/val/조미김_85.txt
#   inflating: img/val/김 김치 쌀밥_90.txt
#   inflating: img/val/조미김_61.txt
#   inflating: img/val/조미김_49.txt
#   inflating: img/val/조미김정식_8.txt
#   inflating: img/val/배추김치_46.jpg
#   inflating: img/val/조미김_23.txt
#   inflating: img/val/김계란후라이_1.txt
#   inflating: img/val/조미김_40.txt
#   inflating: img/val/조미김14.txt
#   inflating: img/val/조미김정식_7.txt
#   inflating: img/val/배추김치_75.jpg
#   inflating: img/val/조미김4.txt
#   inflating: img/val/조미김정식_6.txt
# ...

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !ls
# Out:
# img

# %%
# !pwd
# Out:
# /content/yolov5

# %% [markdown]
# ## Yolov5s 설치

# %%
# !git clone https://github.com/JeongaSeol/PJT03_nutrients_service.git
# Out:
# Cloning into 'PJT03_nutrients_service'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 27 (delta 1), reused 27 (delta 1), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10086, done.
# remote: Total 10086 (delta 0), reused 0 (delta 0), pack-reused 10086
# Receiving objects: 100% (10086/10086), 10.37 MiB | 23.48 MiB/s, done.
# Resolving deltas: 100% (6997/6997), done.

# %%
# %%time

# !pip install -U -r yolov5/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 44.4 MB/s
# ...
#      |████████████████████████████████| 60.3 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 35.9 MB/s
# ...
#      |████████████████████████████████| 62 kB 773 kB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 40.8 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: scipy
# ...

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# %cd /content/yolov5/yolov5
# Out:
# /content/yolov5/yolov5

# %%
# !ls
# Out:
# CONTRIBUTING.md  Dockerfile  LICENSE	requirements.txt  tutorial.ipynb
# data		 export.py   models	setup.cfg	  utils
# detect.py	 hubconf.py  README.md	train.py	  val.py

# %% [markdown]
# - train & valid 폴더를 content/yolov5에 위치
# - data.yaml 파일을 content/yolov5에 위치
#
# 정리하면
# - content/yolov5에 yolov5폴더/train폴더/valid폴더/data.yaml파일
# - content/yolov5/yolov5 폴더에는 train.py파일/models폴더 등이 있음

# %% [markdown]
# ## 테스트 이미지 100장 학습
# #### - class 2개 (mask/no_mask), batch 28, epoch 4000

# %%
# %%time

# !python train.py --img 461 --batch 28 --epochs 4000 --data ../data.yaml --cfg ./models/yolov5s.yaml --weights '' --patience 0 # EarlyStopping 끄기
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  3003/3999     3.62G   0.01221  0.008594 0.0003369       112       480: 100% 2/2 [00:01<00:00,  1.04it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.20s/it]
#                  all         50        212      0.791      0.426      0.493      0.184
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  3004/3999     3.62G    0.0121  0.009106  0.000178        81       480: 100% 2/2 [00:01<00:00,  1.05it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.18s/it]
#                  all         50        212      0.791      0.429      0.499      0.188
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
# ...

# %% [markdown]
# 이미지 100장 class 2, batch 28, epoch 4000 학습 -> 약 4시간 20분 소요

# %%
# %cd /content/yolov5/yolov5/runs/train/exp
# Out:
# /content/yolov5/yolov5/runs/train/exp

# %%
# !ls
# Out:
# confusion_matrix.png				   R_curve.png
# events.out.tfevents.1636014320.56a4688c9764.621.0  results.csv
# F1_curve.png					   results.png
# hyp.yaml					   train_batch0.jpg
# labels_correlogram.jpg				   train_batch1.jpg
# labels.jpg					   train_batch2.jpg
# opt.yaml					   val_batch0_labels.jpg
# P_curve.png					   val_batch0_pred.jpg
# PR_curve.png					   weights

# %%
from IPython.display import Image

# Image('train_batch0.jpg')

# %%
# %cd /content/yolov5/yolov5
# Out:
# /content/yolov5/yolov5

# %%
# !mv /content/yolov5/PJT03_nutrients_service/test_img /content/yolov5/yolov5/

# %% [markdown]
# - content/yolov5에 train/valid에 사용하지 않은 test.jpg 이미지들(test1.jpg ~ test5.jpg)을 위치시키고 test진행

# %%
# !python detect.py --source /content/yolov5/yolov5/test_img/test_1.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# Out:
# detect: weights=['/content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt'], source=/content/yolov5/yolov5/test_img/test_1.jpg, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-114-ga4207a2 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/yolov5/test_img/test_1.jpg: 480x640 1 class0, 1 class3, Done. (0.031s)
# Speed: 0.5ms pre-process, 31.4ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# !python detect.py --source /content/yolov5/yolov5/test_img/test_2.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_3.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_4.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_5.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_6.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_7.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_8.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_9.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_10.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_11.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_12.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# !python detect.py --source /content/yolov5/yolov5/test_img/test_13.jpg --weights /content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt --conf 0.3
# Out:
# detect: weights=['/content/yolov5/PJT03_nutrients_service/yolov5/yolov5s.pt'], source=/content/yolov5/yolov5/test_img/test_2.jpg, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-114-ga4207a2 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/yolov5/test_img/test_2.jpg: 480x640 1 class0, 1 class1, 1 class3, 1 class5, Done. (0.033s)
# Speed: 0.6ms pre-process, 32.6ms inference, 5.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
# ...

# %%
import cv2

# cv2.imwrite('test1.jpg')
img = cv2.imread('/content/yolov5/yolov5/test_img/test8.jpg')
img = cv2.resize(img, None, fx = 0.3, fy = 0.3) 
cv2.imwrite('test8.jpg', img)
# Out:
# True

# %%
Image('/content/yolov5/yolov5/runs/detect/exp/test_1.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp2/test_2.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp3/test_3.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp4/test_4.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp5/test_5.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp6/test_6.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp7/test_7.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp8/test_8.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp9/test_9.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp10/test_10.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp11/test_11.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp12/test_12.jpg')

# %%
Image('/content/yolov5/yolov5/runs/detect/exp13/test_13.jpg')
